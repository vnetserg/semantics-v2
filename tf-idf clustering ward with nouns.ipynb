# %%
import datetime, itertools, sys
import pandas as ps
from subprocess import Popen, PIPE
from multiprocessing import Pool
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import classification_report
from scipy.cluster.hierarchy import ward, fcluster
import matplotlib.pyplot as plt
from pymystem3 import Mystem
import nltk

# %%
data = ps.read_csv("data/spelled-cl.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
data = data[~data["cluster"].isin(["-", "S", "Standard "])]
print("Число записей в таблице:", len(data))
# Out:
# Число записей в таблице: 32317

# %% [markdown]
# ## Подбор оптимального порога для каждого дня

# %%
def do_stem(df):
    mystem = Mystem()
    messages = ["".join(mystem.lemmatize(row["title"] + ". " + row["text"])) for _, row in df.iterrows()]
    nouns_sets = [get_message_nouns(msg, mystem) for msg in messages]
    clusters = [row["cluster"] for _, row in df.iterrows()]
    mystem.close()
    return messages, nouns_sets, clusters

# %%
stop_words = set(nltk.corpus.stopwords.words('russian'))

def get_message_nouns(msg, mystem):
    nouns = set()
    words = mystem.analyze(msg)
    for w in words:
        if "analysis" not in w:
            continue
        if w["analysis"] and "S" in w["analysis"][0]["gr"]:
            lex = w["analysis"][0]["lex"]
            if lex and len(lex) > 2 and lex not in stop_words:
                nouns.add(lex)
        elif not w["analysis"] and len(w["text"]) > 2:
            nouns.add(w["text"].lower())
    return nouns

# %%
def get_optimal_threshold(data_1d, clsize=None):
    if type(data_1d) is tuple:
        data_1d, clsize = data_1d
    messages, noun_sets, clusters = do_stem(data_1d)
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    dist_matrix = 1 - cosine_similarity(tfidf_matrix)
    linkage_matrix = ward(dist_matrix)
    th, res = optimise_threshold(linkage_matrix, noun_sets, clusters, clsize)
    return th, res

# %%
def optimise_threshold(linkage_matrix, noun_sets, clusters, clsize=None):
    scores = {}
    for i in range(10, 21):
        th = i/10
        labels = get_labels(linkage_matrix, noun_sets, clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    for i in range(int(th_m*100) - 9, int(th_m*100) + 10):
        th = i/100
        labels = get_labels(linkage_matrix, noun_sets, clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    return th_m, marks_to_pairwise(clusters, get_labels(linkage_matrix, noun_sets, clsize, th_m))

# %%
def marks_to_pairwise(y_cls, p_cls):
    assert len(y_cls) == len(p_cls)
    res = {"ids": [], "y": [], "p": []}
    for i1, i2 in itertools.combinations(range(len(y_cls)), 2):
        res["ids"].append(sorted((i1, i2)))
        res["y"].append(bool(y_cls[i1] == y_cls[i2]))
        res["p"].append(bool(p_cls[i1] == p_cls[i2]))
    return ps.DataFrame(res, index=None)

# %%
def get_prec_recall_f(res, cls):
    pred = res[res["p"] == cls]
    if len(pred) == 0:
        return 0, 0, 0
    prec = len(pred[pred["y"] == cls]) / len(pred)
    act = res[res["y"] == cls]
    if len(act) == 0:
        return 0, 0, 0
    rec = len(act[act["p"] == cls]) / len(act)
    return prec, rec, 2/(1/prec + 1/rec)

# %%
def get_labels(linkage_matrix, noun_sets, max_cls_size=None, cutoff=None):
    n_samples = len(noun_sets)
    clusters = {i: [i] for i in range(n_samples)}
    for i, row in enumerate(linkage_matrix):
        c1, c2, dist, cls_size = row
        c1, c2 = int(c1), int(c2)
        if cutoff and dist > cutoff:
            break
        if not clusters[c1] or not clusters[c2]:
            clusters[n_samples+i] = []
            continue
        
        all_indexes = clusters[c1] + clusters[c2]
        all_nouns = [noun_sets[i] for i in all_indexes]
        common_nouns = all_nouns[0]
        for nouns in all_nouns[1:]:
            common_nouns &= nouns
        if not common_nouns:
            clusters[n_samples+i] = []
            continue
        
        if not (max_cls_size and cls_size > max_cls_size):
            clusters[n_samples+i] = clusters[c1] + clusters[c2]
            del clusters[c1]
            del clusters[c2]
        else:
            clusters[n_samples+i] = []
    
    labels = [None] * n_samples
    for cls_num, objects in clusters.items():
        for o in objects:
            labels[o] = cls_num
    return labels

# %%
def cross_class_report(res):
    classes = res["y"].unique()
    table = ps.DataFrame(index=classes, columns=classes)
    for true_cls in classes:
        tmp = res[res["y"] == true_cls]
        for pred_cls in classes:
            table[pred_cls][true_cls] = len(tmp[tmp["p"] == pred_cls])
    return table

# %%
def multiprocess_optimise_th_for_days(data, days, clsize=None):
    pool = Pool()
    day_data = [data[data["date"] == day] for day in days]
    th_res = pool.map(get_optimal_threshold, [(d, clsize) for d in day_data])
    pool.close()
    results = {day: (th, res) for (th, res), day in zip(th_res, days)}
    return results

# %%
day_msg_count = {day: len(df) for day, df in data.groupby("date")}
all_days = [day for day, cnt in day_msg_count.items() if 10 < cnt < 1000]
print("Число дней:", len(all_days))
# Out:
# Число дней: 41

# %%
results = multiprocess_optimise_th_for_days(data, all_days)
for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
    th, res = results[day]
    print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
    print("Порог:", th)
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# День: 2015-10-29 (11 сообщений)
# Порог: 1.2
#              precision    recall  f1-score   support
#
#       False       0.94      1.00      0.97        48
#        True       1.00      0.57      0.73         7
#
# avg / total       0.95      0.95      0.94        55
#
#       False True
# False    48     0
# True      3     4
#
#
# День: 2015-11-29 (15 сообщений)
# Порог: 1.0
#              precision    recall  f1-score   support
#
#       False       0.97      1.00      0.98        96
#        True       1.00      0.67      0.80         9
#
# avg / total       0.97      0.97      0.97       105
#
#       False True
# False    96     0
# True      3     6
#
#
# День: 2015-01-23 (17 сообщений)
# Порог: 1.2
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       132
#        True       0.67      1.00      0.80         4
#
# avg / total       0.99      0.99      0.99       136
#
#       False True
# False   130     2
# True      0     4
#
#
# День: 2015-08-28 (17 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       123
#        True       1.00      1.00      1.00        13
#
# avg / total       1.00      1.00      1.00       136
#
#       False True
# False   123     0
# True      0    13
#
#
# День: 2015-09-29 (18 сообщений)
# Порог: 1.2
#              precision    recall  f1-score   support
#
#       False       0.98      0.98      0.98       143
#        True       0.70      0.70      0.70        10
#
# avg / total       0.96      0.96      0.96       153
#
#       False True
# False   140     3
# True      3     7
#
#
# День: 2015-01-24 (22 сообщений)
# Порог: 1.04
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       224
#        True       0.64      1.00      0.78         7
#
# avg / total       0.99      0.98      0.98       231
#
#       False True
# False   220     4
# True      0     7
#
#
# День: 2015-08-25 (22 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       214
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       231
#
#       False True
# False   214     0
# True      0    17
#
#
# День: 2015-04-30 (24 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       255
#        True       1.00      1.00      1.00        21
#
# avg / total       1.00      1.00      1.00       276
#
#       False True
# False   255     0
# True      0    21
#
#
# День: 2015-09-26 (25 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       283
#        True       1.00      0.94      0.97        17
#
# avg / total       1.00      1.00      1.00       300
#
#       False True
# False   283     0
# True      1    16
#
#
# День: 2015-10-26 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       358
#        True       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00       378
#
#       False True
# False   358     0
# True      0    20
#
#
# День: 2015-11-28 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       0.99      0.99      0.99       356
#        True       0.87      0.91      0.89        22
#
# avg / total       0.99      0.99      0.99       378
#
#       False True
# False   353     3
# True      2    20
#
#
# День: 2015-10-30 (38 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       677
#        True       0.92      0.88      0.90        26
#
# avg / total       0.99      0.99      0.99       703
#
#       False True
# False   675     2
# True      3    23
#
#
# День: 2015-09-30 (41 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       0.99      0.99      0.99       789
#        True       0.86      0.77      0.81        31
#
# avg / total       0.99      0.99      0.99       820
#
#       False True
# False   785     4
# True      7    24
#
#
# День: 2015-03-30 (48 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1091
#        True       0.97      0.89      0.93        37
#
# avg / total       1.00      1.00      1.00      1128
#
#       False True
# False  1090     1
# True      4    33
#
#
# День: 2015-09-28 (51 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1236
#        True       1.00      0.95      0.97        39
#
# avg / total       1.00      1.00      1.00      1275
#
#       False True
# False  1236     0
# True      2    37
#
#
# День: 2015-03-28 (75 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      2712
#        True       1.00      0.97      0.98        63
#
# avg / total       1.00      1.00      1.00      2775
#
#       False True
# False  2712     0
# True      2    61
#
#
# День: 2015-12-23 (81 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3202
#        True       0.88      0.76      0.82        38
#
# avg / total       1.00      1.00      1.00      3240
#
#       False True
# False  3198     4
# True      9    29
#
#
# День: 2015-03-26 (82 сообщений)
# Порог: 1.37
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3259
#        True       1.00      0.94      0.97        62
#
# avg / total       1.00      1.00      1.00      3321
#
#       False True
# False  3259     0
# True      4    58
#
#
# День: 2015-11-27 (87 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3679
#        True       0.94      0.76      0.84        62
#
# avg / total       1.00      1.00      0.99      3741
#
#       False True
# False  3676     3
# True     15    47
#
#
# День: 2015-11-30 (94 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      4298
#        True       0.86      0.89      0.87        73
#
# avg / total       1.00      1.00      1.00      4371
#
#       False True
# False  4287    11
# True      8    65
#
#
# День: 2015-08-30 (102 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5067
#        True       0.89      0.86      0.87        84
#
# avg / total       1.00      1.00      1.00      5151
#
#       False True
# False  5058     9
# True     12    72
#
#
# День: 2016-02-06 (104 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5277
#        True       0.97      0.96      0.97        79
#
# avg / total       1.00      1.00      1.00      5356
#
#       False True
# False  5275     2
# True      3    76
#
#
# День: 2015-08-29 (111 сообщений)
# Порог: 1.22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6021
#        True       0.91      0.85      0.88        84
#
# avg / total       1.00      1.00      1.00      6105
#
#       False True
# False  6014     7
# True     13    71
#
#
# День: 2015-11-26 (118 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6812
#        True       0.82      0.86      0.84        91
#
# avg / total       1.00      1.00      1.00      6903
#
#       False True
# False  6795    17
# True     13    78
#
#
# День: 2015-09-27 (119 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6935
#        True       0.99      0.87      0.93        86
#
# avg / total       1.00      1.00      1.00      7021
#
#       False True
# False  6934     1
# True     11    75
#
#
# День: 2015-11-25 (121 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      7177
#        True       0.74      0.75      0.74        83
#
# avg / total       0.99      0.99      0.99      7260
#
#       False True
# False  7155    22
# True     21    62
#
#
# День: 2015-10-25 (144 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     10182
#        True       0.89      0.83      0.86       114
#
# avg / total       1.00      1.00      1.00     10296
#
#        False True
# False  10170    12
# True      19    95
#
#
# День: 2015-06-26 (164 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     13250
#        True       0.93      0.91      0.92       116
#
# avg / total       1.00      1.00      1.00     13366
#
#        False True
# False  13242     8
# True      11   105
#
#
# День: 2015-06-25 (217 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     23272
#        True       0.89      0.85      0.87       164
#
# avg / total       1.00      1.00      1.00     23436
#
#        False True
# False  23254    18
# True      24   140
#
#
# День: 2015-05-27 (226 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     25263
#        True       0.88      0.86      0.87       162
#
# avg / total       1.00      1.00      1.00     25425
#
#        False True
# False  25243    20
# True      22   140
#
#
# День: 2015-05-28 (236 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     27567
#        True       0.87      0.92      0.90       163
#
# avg / total       1.00      1.00      1.00     27730
#
#        False True
# False  27545    22
# True      13   150
#
#
# День: 2015-03-25 (240 сообщений)
# Порог: 1.51
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     28515
#        True       0.91      0.95      0.93       165
#
# avg / total       1.00      1.00      1.00     28680
#
#        False True
# False  28499    16
# True       8   157
#
#
# День: 2015-05-25 (259 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33225
#        True       0.82      0.84      0.83       186
#
# avg / total       1.00      1.00      1.00     33411
#
#        False True
# False  33190    35
# True      30   156
#
#
# День: 2015-02-27 (262 сообщений)
# Порог: 1.66
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33946
#        True       0.95      0.85      0.90       245
#
# avg / total       1.00      1.00      1.00     34191
#
#        False True
# False  33935    11
# True      37   208
#
#
# День: 2015-02-25 (279 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     38565
#        True       0.99      0.87      0.93       216
#
# avg / total       1.00      1.00      1.00     38781
#
#        False True
# False  38564     1
# True      28   188
#
#
# День: 2015-05-29 (281 сообщений)
# Порог: 1.25
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39128
#        True       0.72      0.83      0.77       212
#
# avg / total       1.00      1.00      1.00     39340
#
#        False True
# False  39058    70
# True      36   176
#
#
# День: 2015-02-26 (288 сообщений)
# Порог: 1.47
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     41029
#        True       0.90      0.75      0.81       299
#
# avg / total       1.00      1.00      1.00     41328
#
#        False True
# False  41003    26
# True      76   223
#
#
# День: 2015-05-26 (315 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     49230
#        True       0.68      0.85      0.76       225
#
# avg / total       1.00      1.00      1.00     49455
#
#        False True
# False  49141    89
# True      34   191
#
#
# День: 2015-03-29 (393 сообщений)
# Порог: 1.33
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     76724
#        True       0.69      0.82      0.75       304
#
# avg / total       1.00      1.00      1.00     77028
#
#        False True
# False  76614   110
# True      54   250
#
#
# День: 2015-05-30 (523 сообщений)
# Порог: 1.39
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    136121
#        True       0.60      0.80      0.69       382
#
# avg / total       1.00      1.00      1.00    136503
#
#         False True
# False  135919   202
# True       77   305
#
#
# День: 2015-02-28 (536 сообщений)
# Порог: 1.74
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    142727
#        True       0.87      0.84      0.85       653
#
# avg / total       1.00      1.00      1.00    143380
#
#         False True
# False  142643    84
# True      105   548

# %%
data_cl = ps.read_csv("data/day-1432-cl.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
th, res = get_optimal_threshold(data_cl)
print("Порог:", th)
print(classification_report(res["y"], res["p"]))
print(cross_class_report(res), "\n\n")
# Out:
# Порог: 1.76
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1014749
#        True       0.63      0.77      0.69      1276
#
# avg / total       1.00      1.00      1.00   1016025
#
#       True     False
# True    981      295
# False   578  1014171

# %%
res = get_clusterization_results(data_cl, 1.5)
print(classification_report(res["y"], res["p"]))
print(cross_class_report(res), "\n\n")
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1014749
#        True       0.76      0.61      0.67      1276
#
# avg / total       1.00      1.00      1.00   1016025
#
#       True     False
# True    777      499
# False   250  1014499

# %% [markdown]
# ## Многопроцессная обработка с фиксированным порогом

# %%
def multiprocess_apply_th(data, days, th=None, clsize=None):
    pool = Pool()
    day_data = [data[data["date"] == day] for day in days]
    results = pool.map(get_clusterization_results, [(d, th, clsize) for d in day_data])
    pool.close()
    return {day: res for day, res in zip(days, results)}

# %%
def get_clusterization_results(data_1d, th=None, clsize=None):
    if type(data_1d) is tuple:
        data_1d, th, clsize = data_1d
    messages, noun_sets, clusters = do_stem(data_1d)
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    dist_matrix = 1 - cosine_similarity(tfidf_matrix)
    linkage_matrix = ward(dist_matrix)
    labels = get_labels(linkage_matrix, noun_sets, clsize, th)
    res = marks_to_pairwise(clusters, labels)
    return res

# %%
results = multiprocess_apply_th(data, all_days, th=2.0)
for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
    res = results[day]
    print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e017f4aaa75d> in <module>()
# ----> 1 results = multiprocess_apply_th(data, all_days, th=2.0)
#       2 for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
#       3     res = results[day]
#       4     print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
#       5     print(classification_report(res["y"], res["p"]))
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Выбор дней из полной выборки

# %%
data_all = ps.read_csv("data/120k-utf8.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
data_all = data_all[~data_all["cluster"].isin(["S", "Standard "])]
print("Число записей в таблице:", len(data_all))
# Out:
# Число записей в таблице: 117751

# %%
no_cluster_index = 0
for i, ind in enumerate(data_all[data_all["cluster"] == "-"].index):
    data_all.loc[ind]["cluster"] = "NONE_{}".format(i)

# %%
days_cnt = {}
for day in data_all["date"].unique():
    cnt = (data_all["date"] == day).value_counts()[True]
    if 1000 < cnt < 5000:
        days_cnt[day] = cnt
for day, cnt in sorted(days_cnt.items(), key=lambda x: x[1]):
    print(day, cnt)
# Out:
# 2015-06-25 1120
# 2015-03-25 1127
# 2015-05-27 1137
# 2015-03-29 1145
# 2015-02-25 1158
# 2015-02-26 1159
# 2015-05-25 1164
# 2015-05-29 1183
# 2015-02-27 1191
# 2015-05-26 1212
# 2015-02-28 1432
# 2015-05-30 1465
# 2016-01-28 4146

# %%
days = ["2015-02-28", "2016-01-28"]
results = multiprocess_apply_th(data_all, days, th=2.0)
for day in sorted(results.keys(), key=lambda x: days_cnt[x]):
    res = results[day]
    print("День: {} ({} сообщений)".format(day, days_cnt[day]))
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-3f2b9874dba8> in <module>()
#       1 days = ["2015-02-28", "2016-01-28"]
# ----> 2 results = multiprocess_apply_th(data_all, days, th=2.0)
#       3 for day in sorted(results.keys(), key=lambda x: days_cnt[x]):
#       4     res = results[day]
#       5     print("День: {} ({} сообщений)".format(day, days_cnt[day]))
#
# <ipython-input-12-3911eaf1decd> in multiprocess_apply_th(data, days, th, clsize)
#       2     pool = Pool()
#       3     day_data = [data[data["date"] == day] for day in days]
# ----> 4     results = pool.map(get_clusterization_results, [(d, th, clsize) for d in day_data])
#       5     pool.close()
#       6     return {day: res for day, res in zip(days, results)}
#
# /usr/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
days = ["2015-02-28", "2016-01-28"]
results = multiprocess_apply_th(data_all, days, th=3.0)
for day in sorted(results.keys(), key=lambda x: days_cnt[x]):
    res = results[day]
    print("День: {} ({} сообщений)".format(day, days_cnt[day]))
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# День: 2015-02-28 (1432 сообщений)
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1024181
#        True       0.10      0.87      0.18       415
#
# avg / total       1.00      1.00      1.00   1024596
#
#          False True
# False  1020935  3246
# True        56   359
#
#
# День: 2016-01-28 (4146 сообщений)
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   8591695
#        True       0.07      0.83      0.14       890
#
# avg / total       1.00      1.00      1.00   8592585
#
#          False True
# False  8582598  9097
# True       154   736

# %% [markdown]
# ## Анализ ошибок кластеризации

# %%
def export_clusterization_report(data_1d, cutoff, filename):
    messages, noun_sets, clusters = do_stem(data_1d)
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    dist_matrix = 1 - cosine_similarity(tfidf_matrix)
    linkage_matrix = ward(dist_matrix)
    labels = get_labels(linkage_matrix, noun_sets, cutoff=cutoff)
    
    res = marks_to_pairwise(clusters, labels)
    print("ДЕНЬ: {}\nСообщений: {}".format(data_1d.iloc[0]["date"], len(data_1d)))
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
    
    texts = [row["title"] + ". " + row["text"] for _, row in data_1d.iterrows()]
    results = ps.DataFrame({"message": texts, "y": clusters, "p": labels}, index=None)
    with open(filename, "w") as f:
        for _, df in results.groupby("p"):
            if len(df["y"].unique()) == 1:
                continue
            df = df.sort_values("y")
            cluster_letter = {c: l for c, l in zip(sorted(df["y"].unique()), "абвгдежзиклмно")}
            f.write("Участвующие кластеры:\n")
            for c, l in sorted(cluster_letter.items(), key=lambda x: x[0]):
                f.write("  {}) '{}'\n".format(l, c))
            f.write("Сообщения:\n")
            for _, row in df.iterrows():
                f.write("  ({}) {}\n".format(cluster_letter[row["y"]], row["message"]))
            f.write("\n")

# %%
days = ["2015-02-28", "2016-01-28"]
for day in days:
    export_clusterization_report(data_all[data_all["date"] == day], 1.75,
                                 "reports-full/report-full-{}.txt".format(day))
# Out:
# ДЕНЬ: 2015-02-28
# Сообщений: 1432
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1024181
#        True       0.20      0.77      0.32       415
#
# avg / total       1.00      1.00      1.00   1024596
#
#          False True
# False  1022937  1244
# True        97   318
#
#
# ДЕНЬ: 2016-01-28
# Сообщений: 4146
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   8591695
#        True       0.24      0.68      0.36       890
#
# avg / total       1.00      1.00      1.00   8592585
#
#          False True
# False  8589801  1894
# True       287   603

# %%
for day in days:
    data_1d = data_all[data_all["date"] == day].copy()
    data_1d.sort_values("cluster", inplace=True)
    data_1d.to_csv("data/day-{}.csv".format(len(data_1d)), sep=';', header=None)

# %%
for filename in ["day-1432.csv", "day-4146.csv"]:
    data_1d = ps.read_csv("data/" + filename, sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
    export_clusterization_report(data_1d, 1.75,
                                 "reports-full/report-{}.txt".format(filename.split(".")[0]))
# Out:
# ДЕНЬ: 2015-02-28
# Сообщений: 1432
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1024181
#        True       0.20      0.77      0.32       415
#
# avg / total       1.00      1.00      1.00   1024596
#
#       True     False
# True    318       97
# False  1244  1022937
#
#
# ДЕНЬ: 2016-01-28
# Сообщений: 4146
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   8591695
#        True       0.24      0.68      0.36       890
#
# avg / total       1.00      1.00      1.00   8592585
#
#          False True
# False  8589801  1894
# True       287   603
