# %%
import datetime, itertools, sys
import pandas as ps
from subprocess import Popen, PIPE
from multiprocessing import Pool
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import classification_report
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from scipy.cluster.hierarchy import ward, fcluster
import matplotlib.pyplot as plt
from pymystem3 import Mystem
import nltk

# %%
data = ps.read_csv("data/spelled-f.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
data = data[~data["cluster"].isin(["-", "S", "Standard "])]
print("Число записей в таблице:", len(data))
# Out:
# Число записей в таблице: 32317

# %% [markdown]
# ## LSA для одного дня

# %%
def do_stem(df):
    mystem = Mystem()
    messages = ["".join(mystem.lemmatize(row["title"] + ". " + row["text"])) for _, row in df.iterrows()]
    clusters = [row["cluster"] for _, row in df.iterrows()]
    mystem.close()
    return messages, clusters

# %%
def get_lsa_matrix(data_1d, n_features=1500):
    messages, clusters = do_stem(data_1d)
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    
    if tfidf_matrix.shape[1] <= n_features:
        return tfidf_matrix, clusters
    
    svd = TruncatedSVD(n_features)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    lsa_matrix = lsa.fit_transform(tfidf_matrix)
    return lsa_matrix, clusters

# %%
def marks_to_pairwise(y_cls, p_cls):
    assert len(y_cls) == len(p_cls)
    res = {"ids": [], "y": [], "p": []}
    for i1, i2 in itertools.combinations(range(len(y_cls)), 2):
        res["ids"].append(sorted((i1, i2)))
        res["y"].append(bool(y_cls[i1] == y_cls[i2]))
        res["p"].append(bool(p_cls[i1] == p_cls[i2]))
    return ps.DataFrame(res, index=None)

# %%
def cross_class_report(res):
    classes = res["y"].unique()
    table = ps.DataFrame(index=classes, columns=classes)
    for true_cls in classes:
        tmp = res[res["y"] == true_cls]
        for pred_cls in classes:
            table[pred_cls][true_cls] = len(tmp[tmp["p"] == pred_cls])
    return table

# %%
data_1d = data[data["date"] == "2016-02-05"]
lsa_matrix, clusters = get_lsa_matrix(data_1d, 1500)
dist_matrix = 1 - cosine_similarity(lsa_matrix)
linkage_matrix = ward(dist_matrix)

# %%
labels = fcluster(linkage_matrix, 2, criterion='distance')
res = marks_to_pairwise(clusters, labels)
print(classification_report(res["y"], res["p"]))
print(cross_class_report(res), "\n\n")
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   6307362
#        True       0.70      0.72      0.71      2766
#
# avg / total       1.00      1.00      1.00   6310128
#
#          False True
# False  6306512   850
# True       772  1994

# %% [markdown]
# ## Подбор оптимального порога для каждого дня

# %%
def multiprocess_optimise_th_for_days(days, clsize=None):
    pool = Pool()
    day_data = [data[data["date"] == day] for day in days]
    th_res = pool.map(get_optimal_threshold, [(d, clsize) for d in day_data])
    pool.close()
    results = {day: (th, res) for (th, res), day in zip(th_res, days)}
    return results

# %%
def get_optimal_threshold(data_1d, clsize=None):
    if type(data_1d) is tuple:
        data_1d, clsize = data_1d
    
    lsa_matrix, clusters = get_lsa_matrix(data_1d)
    
    '''
    messages, clusters = do_stem(data_1d)
    
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    
    svd = TruncatedSVD(100)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    lsa_matrix = lsa.fit_transform(tfidf_matrix)
    '''
    
    dist_matrix = 1 - cosine_similarity(lsa_matrix)
    linkage_matrix = ward(dist_matrix)
    th, res = optimise_threshold(linkage_matrix, clusters, clsize)
    return th, res

# %%
def optimise_threshold(linkage_matrix, clusters, clsize=None):
    scores = {}
    for i in range(10, 21):
        th = i/10
        labels = get_labels(linkage_matrix, len(clusters), clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    for i in range(int(th_m*100) - 9, int(th_m*100) + 10):
        th = i/100
        labels = get_labels(linkage_matrix, len(clusters), clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    return th_m, marks_to_pairwise(clusters, get_labels(linkage_matrix, len(clusters), clsize, th_m))

# %%
def get_labels(linkage_matrix, n_samples, max_cls_size=None, cutoff=None):
    clusters = {i: [i] for i in range(n_samples)}
    for i, row in enumerate(linkage_matrix):
        c1, c2, dist, cls_size = row
        if cutoff and dist > cutoff:
            break
        if not (max_cls_size and cls_size > max_cls_size):
            clusters[n_samples+i] = clusters[c1] + clusters[c2]
            del clusters[c1]
            del clusters[c2]
    labels = [None] * n_samples
    for cls_num, objects in clusters.items():
        for o in objects:
            labels[o] = cls_num
    return labels

# %%
def get_prec_recall_f(res, cls):
    pred = res[res["p"] == cls]
    if len(pred) == 0:
        return 0, 0, 0
    prec = len(pred[pred["y"] == cls]) / len(pred)
    act = res[res["y"] == cls]
    if len(act) == 0:
        return 0, 0, 0
    rec = len(act[act["p"] == cls]) / len(act)
    return prec, rec, 2/(1/prec + 1/rec)

# %%
day_msg_count = {day: len(df) for day, df in data.groupby("date")}
all_days = [day for day, cnt in day_msg_count.items() if 10 < cnt < 4000]
print("Число дней:", len(all_days))
# Out:
# Число дней: 44

# %%
results = multiprocess_optimise_th_for_days(all_days)
for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
    th, res = results[day]
    print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
    print("Порог:", th)
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# День: 2015-10-29 (11 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       0.96      1.00      0.98        48
#        True       1.00      0.71      0.83         7
#
# avg / total       0.97      0.96      0.96        55
#
#       False True
# False    48     0
# True      2     5
#
#
# День: 2015-11-29 (15 сообщений)
# Порог: 1.06
#              precision    recall  f1-score   support
#
#       False       0.98      0.99      0.98        96
#        True       0.88      0.78      0.82         9
#
# avg / total       0.97      0.97      0.97       105
#
#       False True
# False    95     1
# True      2     7
#
#
# День: 2015-01-23 (17 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       132
#        True       0.57      1.00      0.73         4
#
# avg / total       0.99      0.98      0.98       136
#
#       False True
# False   129     3
# True      0     4
#
#
# День: 2015-08-28 (17 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       123
#        True       1.00      1.00      1.00        13
#
# avg / total       1.00      1.00      1.00       136
#
#       False True
# False   123     0
# True      0    13
#
#
# День: 2015-09-29 (18 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       0.99      0.98      0.98       143
#        True       0.73      0.80      0.76        10
#
# avg / total       0.97      0.97      0.97       153
#
#       False True
# False   140     3
# True      2     8
#
#
# День: 2015-01-24 (22 сообщений)
# Порог: 1.04
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       224
#        True       0.64      1.00      0.78         7
#
# avg / total       0.99      0.98      0.98       231
#
#       False True
# False   220     4
# True      0     7
#
#
# День: 2015-08-25 (22 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       214
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       231
#
#       False True
# False   214     0
# True      0    17
#
#
# День: 2015-04-30 (24 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       255
#        True       1.00      1.00      1.00        21
#
# avg / total       1.00      1.00      1.00       276
#
#       False True
# False   255     0
# True      0    21
#
#
# День: 2015-09-26 (25 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       283
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       300
#
#       False True
# False   283     0
# True      0    17
#
#
# День: 2015-11-28 (28 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       0.99      0.99      0.99       356
#        True       0.83      0.91      0.87        22
#
# avg / total       0.98      0.98      0.98       378
#
#       False True
# False   352     4
# True      2    20
#
#
# День: 2015-10-26 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       358
#        True       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00       378
#
#       False True
# False   358     0
# True      0    20
#
#
# День: 2015-10-30 (38 сообщений)
# Порог: 0.99
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      1.00       677
#        True       0.96      0.85      0.90        26
#
# avg / total       0.99      0.99      0.99       703
#
#       False True
# False   676     1
# True      4    22
#
#
# День: 2015-09-30 (41 сообщений)
# Порог: 1.02
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      0.99       789
#        True       1.00      0.74      0.85        31
#
# avg / total       0.99      0.99      0.99       820
#
#       False True
# False   789     0
# True      8    23
#
#
# День: 2015-03-30 (48 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1091
#        True       0.97      0.95      0.96        37
#
# avg / total       1.00      1.00      1.00      1128
#
#       False True
# False  1090     1
# True      2    35
#
#
# День: 2015-09-28 (51 сообщений)
# Порог: 1.51
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1236
#        True       1.00      1.00      1.00        39
#
# avg / total       1.00      1.00      1.00      1275
#
#       False True
# False  1236     0
# True      0    39
#
#
# День: 2015-03-28 (75 сообщений)
# Порог: 1.39
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      2712
#        True       1.00      1.00      1.00        63
#
# avg / total       1.00      1.00      1.00      2775
#
#       False True
# False  2712     0
# True      0    63
#
#
# День: 2015-12-23 (81 сообщений)
# Порог: 1.18
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3202
#        True       0.83      0.89      0.86        38
#
# avg / total       1.00      1.00      1.00      3240
#
#       False True
# False  3195     7
# True      4    34
#
#
# День: 2015-03-26 (82 сообщений)
# Порог: 1.37
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3259
#        True       1.00      0.97      0.98        62
#
# avg / total       1.00      1.00      1.00      3321
#
#       False True
# False  3259     0
# True      2    60
#
#
# День: 2015-11-27 (87 сообщений)
# Порог: 1.38
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3679
#        True       0.92      0.89      0.90        62
#
# avg / total       1.00      1.00      1.00      3741
#
#       False True
# False  3674     5
# True      7    55
#
#
# День: 2015-11-30 (94 сообщений)
# Порог: 1.43
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      4298
#        True       0.86      0.95      0.90        73
#
# avg / total       1.00      1.00      1.00      4371
#
#       False True
# False  4287    11
# True      4    69
#
#
# День: 2015-08-30 (102 сообщений)
# Порог: 1.36
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5067
#        True       0.93      0.89      0.91        84
#
# avg / total       1.00      1.00      1.00      5151
#
#       False True
# False  5061     6
# True      9    75
#
#
# День: 2016-02-06 (104 сообщений)
# Порог: 1.29
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5277
#        True       0.97      0.99      0.98        79
#
# avg / total       1.00      1.00      1.00      5356
#
#       False True
# False  5275     2
# True      1    78
#
#
# День: 2015-08-29 (111 сообщений)
# Порог: 1.22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6021
#        True       0.91      0.87      0.89        84
#
# avg / total       1.00      1.00      1.00      6105
#
#       False True
# False  6014     7
# True     11    73
#
#
# День: 2015-11-26 (118 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6812
#        True       0.84      0.96      0.89        91
#
# avg / total       1.00      1.00      1.00      6903
#
#       False True
# False  6795    17
# True      4    87
#
#
# День: 2015-09-27 (119 сообщений)
# Порог: 1.33
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6935
#        True       0.99      0.90      0.94        86
#
# avg / total       1.00      1.00      1.00      7021
#
#       False True
# False  6934     1
# True      9    77
#
#
# День: 2015-11-25 (121 сообщений)
# Порог: 1.26
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      7177
#        True       0.84      0.80      0.81        83
#
# avg / total       1.00      1.00      1.00      7260
#
#       False True
# False  7164    13
# True     17    66
#
#
# День: 2015-10-25 (144 сообщений)
# Порог: 1.42
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     10182
#        True       0.91      0.88      0.89       114
#
# avg / total       1.00      1.00      1.00     10296
#
#        False True
# False  10172    10
# True      14   100
#
#
# День: 2015-06-26 (164 сообщений)
# Порог: 1.22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     13250
#        True       0.92      0.95      0.93       116
#
# avg / total       1.00      1.00      1.00     13366
#
#        False True
# False  13240    10
# True       6   110
#
#
# День: 2015-06-25 (217 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     23272
#        True       0.86      0.93      0.89       164
#
# avg / total       1.00      1.00      1.00     23436
#
#        False True
# False  23247    25
# True      11   153
#
#
# День: 2015-05-27 (226 сообщений)
# Порог: 1.37
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     25263
#        True       0.87      0.89      0.88       162
#
# avg / total       1.00      1.00      1.00     25425
#
#        False True
# False  25242    21
# True      18   144
#
#
# День: 2015-05-28 (236 сообщений)
# Порог: 1.24
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     27567
#        True       0.93      0.94      0.93       163
#
# avg / total       1.00      1.00      1.00     27730
#
#        False True
# False  27555    12
# True      10   153
#
#
# День: 2015-03-25 (240 сообщений)
# Порог: 1.45
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     28515
#        True       0.89      0.96      0.92       165
#
# avg / total       1.00      1.00      1.00     28680
#
#        False True
# False  28496    19
# True       7   158
#
#
# День: 2015-05-25 (259 сообщений)
# Порог: 1.19
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33225
#        True       0.91      0.81      0.85       186
#
# avg / total       1.00      1.00      1.00     33411
#
#        False True
# False  33210    15
# True      36   150
#
#
# День: 2015-02-27 (262 сообщений)
# Порог: 1.33
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     34009
#        True       0.92      0.95      0.93       182
#
# avg / total       1.00      1.00      1.00     34191
#
#        False True
# False  33995    14
# True      10   172
#
#
# День: 2015-02-25 (279 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     38577
#        True       0.98      0.95      0.96       204
#
# avg / total       1.00      1.00      1.00     38781
#
#        False True
# False  38574     3
# True      11   193
#
#
# День: 2015-05-29 (281 сообщений)
# Порог: 1.25
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39128
#        True       0.72      0.85      0.78       212
#
# avg / total       1.00      1.00      1.00     39340
#
#        False True
# False  39058    70
# True      32   180
#
#
# День: 2015-02-26 (288 сообщений)
# Порог: 1.38
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     41120
#        True       0.79      0.86      0.82       208
#
# avg / total       1.00      1.00      1.00     41328
#
#        False True
# False  41073    47
# True      29   179
#
#
# День: 2015-05-26 (315 сообщений)
# Порог: 1.41
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     49230
#        True       0.71      0.86      0.78       225
#
# avg / total       1.00      1.00      1.00     49455
#
#        False True
# False  49151    79
# True      32   193
#
#
# День: 2015-03-29 (393 сообщений)
# Порог: 1.33
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     76724
#        True       0.70      0.84      0.76       304
#
# avg / total       1.00      1.00      1.00     77028
#
#        False True
# False  76613   111
# True      49   255
#
#
# День: 2015-05-30 (523 сообщений)
# Порог: 1.39
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    136121
#        True       0.60      0.83      0.70       382
#
# avg / total       1.00      1.00      1.00    136503
#
#         False True
# False  135914   207
# True       66   316
#
#
# День: 2015-02-28 (536 сообщений)
# Порог: 1.44
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    142965
#        True       0.68      0.84      0.75       415
#
# avg / total       1.00      1.00      1.00    143380
#
#         False True
# False  142804   161
# True       68   347
#
#
# День: 2016-01-28 (1189 сообщений)
# Порог: 1.49
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    705376
#        True       0.75      0.82      0.78       890
#
# avg / total       1.00      1.00      1.00    706266
#
#         False True
# False  705133   243
# True      158   732
#
#
# День: 2016-01-26 (1865 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1736676
#        True       0.43      0.44      0.44      1504
#
# avg / total       1.00      1.00      1.00   1738180
#
#          False True
# False  1735800   876
# True       841   663
#
#
# День: 2016-02-05 (3553 сообщений)
# Порог: 2.02
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   6307362
#        True       0.69      0.73      0.71      2766
#
# avg / total       1.00      1.00      1.00   6310128
#
#          False True
# False  6306474   888
# True       748  2018
