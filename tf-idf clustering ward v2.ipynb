# %%
import datetime, itertools, sys
from functools import partial
import pandas as ps
from subprocess import Popen, PIPE
from multiprocessing import Pool
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import classification_report
from scipy.cluster.hierarchy import ward, fcluster
import matplotlib.pyplot as plt
from pymystem3 import Mystem
import nltk

# %%
data = ps.read_csv("data/spelled-cl.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
data = data[~data["cluster"].isin(["-", "S", "Standard "])]
print("Число записей в таблице:", len(data))
# Out:
# Число записей в таблице: 32317

# %%
data_1d = data[data["date"] == "2015-05-30"]
print(len(data_1d))
# Out:
# 523

# %% [markdown]
# ## Подбор оптимального порога для каждого дня

# %%
def do_stem(df):
    mystem = Mystem()
    messages = ["".join(mystem.lemmatize(row["title"] + ". " + row["text"])) for _, row in df.iterrows()]
    clusters = [row["cluster"] for _, row in df.iterrows()]
    mystem.close()
    return messages, clusters

# %%
def get_optimal_threshold(data_1d, clsize=None):
    if type(data_1d) is tuple:
        data_1d, clsize = data_1d
    messages, clusters = do_stem(data_1d)
    
    if len(data_1d) > 100:
        max_df = 0.1
    else:
        max_df = 1.0
    
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000, max_df=max_df,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    dist_matrix = 1 - cosine_similarity(tfidf_matrix)
    linkage_matrix = ward(dist_matrix)
    th, res = optimise_threshold(linkage_matrix, clusters, clsize)
    return th, res

# %%
def optimise_threshold(linkage_matrix, clusters, clsize=None):
    scores = {}
    for i in range(10, 21):
        th = i/10
        labels = get_labels(linkage_matrix, len(clusters), clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    for i in range(int(th_m*100) - 9, int(th_m*100) + 10):
        th = i/100
        labels = get_labels(linkage_matrix, len(clusters), clsize, th)
        res = marks_to_pairwise(clusters, labels)
        _, _, fscore = get_prec_recall_f(res, 1)
        fscore = int(fscore*10000)/10000
        scores[th] = fscore
    fscore_m, th_m = max((f, th) for th, f in scores.items())
    max_fscores = sorted([(f, th) for th, f in scores.items() if f == fscore_m])
    th_m = max_fscores[len(max_fscores)//2][1]
    return th_m, marks_to_pairwise(clusters, get_labels(linkage_matrix, len(clusters), clsize, th_m))

# %%
def marks_to_pairwise(y_cls, p_cls):
    assert len(y_cls) == len(p_cls)
    res = {"ids": [], "y": [], "p": []}
    for i1, i2 in itertools.combinations(range(len(y_cls)), 2):
        res["ids"].append(sorted((i1, i2)))
        res["y"].append(bool(y_cls[i1] == y_cls[i2]))
        res["p"].append(bool(p_cls[i1] == p_cls[i2]))
    return ps.DataFrame(res, index=None)

# %%
def get_prec_recall_f(res, cls):
    pred = res[res["p"] == cls]
    if len(pred) == 0:
        return 0, 0, 0
    prec = len(pred[pred["y"] == cls]) / len(pred)
    act = res[res["y"] == cls]
    if len(act) == 0:
        return 0, 0, 0
    rec = len(act[act["p"] == cls]) / len(act)
    return prec, rec, 2/(1/prec + 1/rec)

# %%
def get_labels(linkage_matrix, n_samples, max_cls_size=None, cutoff=None):
    clusters = {i: [i] for i in range(n_samples)}
    for i, row in enumerate(linkage_matrix):
        c1, c2, dist, cls_size = row
        if cutoff and dist > cutoff:
            break
        if not (max_cls_size and cls_size > max_cls_size):
            clusters[n_samples+i] = clusters[c1] + clusters[c2]
            del clusters[c1]
            del clusters[c2]
    labels = [None] * n_samples
    for cls_num, objects in clusters.items():
        for o in objects:
            labels[o] = cls_num
    return labels

# %%
def cross_class_report(res):
    classes = res["y"].unique()
    table = ps.DataFrame(index=classes, columns=classes)
    for true_cls in classes:
        tmp = res[res["y"] == true_cls]
        for pred_cls in classes:
            table[pred_cls][true_cls] = len(tmp[tmp["p"] == pred_cls])
    return table

# %%
def multiprocess_optimise_th_for_days(days, clsize=None):
    pool = Pool()
    day_data = [data[data["date"] == day] for day in days]
    th_res = pool.map(get_optimal_threshold, [(d, clsize) for d in day_data])
    pool.close()
    results = {day: (th, res) for (th, res), day in zip(th_res, days)}
    return results

# %%
day_msg_count = {day: len(df) for day, df in data.groupby("date")}
all_days = [day for day, cnt in day_msg_count.items() if 10 < cnt < 1000]
print("Число дней:", len(all_days))
# Out:
# Число дней: 41

# %%
results = multiprocess_optimise_th_for_days(all_days, 3)
for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
    th, res = results[day]
    print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
    print("Порог:", th)
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# День: 2015-10-29 (11 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       0.96      1.00      0.98        48
#        True       1.00      0.71      0.83         7
#
# avg / total       0.97      0.96      0.96        55
#
#       False True
# False    48     0
# True      2     5
#
#
# День: 2015-11-29 (15 сообщений)
# Порог: 1.06
#              precision    recall  f1-score   support
#
#       False       0.98      0.99      0.98        96
#        True       0.88      0.78      0.82         9
#
# avg / total       0.97      0.97      0.97       105
#
#       False True
# False    95     1
# True      2     7
#
#
# День: 2015-08-28 (17 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       123
#        True       1.00      1.00      1.00        13
#
# avg / total       1.00      1.00      1.00       136
#
#       False True
# False   123     0
# True      0    13
#
#
# День: 2015-01-23 (17 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       132
#        True       0.57      1.00      0.73         4
#
# avg / total       0.99      0.98      0.98       136
#
#       False True
# False   129     3
# True      0     4
#
#
# День: 2015-09-29 (18 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       0.99      0.98      0.98       143
#        True       0.73      0.80      0.76        10
#
# avg / total       0.97      0.97      0.97       153
#
#       False True
# False   140     3
# True      2     8
#
#
# День: 2015-01-24 (22 сообщений)
# Порог: 1.04
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       224
#        True       0.64      1.00      0.78         7
#
# avg / total       0.99      0.98      0.98       231
#
#       False True
# False   220     4
# True      0     7
#
#
# День: 2015-08-25 (22 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       214
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       231
#
#       False True
# False   214     0
# True      0    17
#
#
# День: 2015-04-30 (24 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       255
#        True       1.00      1.00      1.00        21
#
# avg / total       1.00      1.00      1.00       276
#
#       False True
# False   255     0
# True      0    21
#
#
# День: 2015-09-26 (25 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       283
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       300
#
#       False True
# False   283     0
# True      0    17
#
#
# День: 2015-11-28 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       0.99      0.99      0.99       356
#        True       0.90      0.82      0.86        22
#
# avg / total       0.98      0.98      0.98       378
#
#       False True
# False   354     2
# True      4    18
#
#
# День: 2015-10-26 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       358
#        True       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00       378
#
#       False True
# False   358     0
# True      0    20
#
#
# День: 2015-10-30 (38 сообщений)
# Порог: 0.99
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      1.00       677
#        True       0.96      0.85      0.90        26
#
# avg / total       0.99      0.99      0.99       703
#
#       False True
# False   676     1
# True      4    22
#
#
# День: 2015-09-30 (41 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      1.00       789
#        True       0.96      0.81      0.88        31
#
# avg / total       0.99      0.99      0.99       820
#
#       False True
# False   788     1
# True      6    25
#
#
# День: 2015-03-30 (48 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1091
#        True       0.97      0.95      0.96        37
#
# avg / total       1.00      1.00      1.00      1128
#
#       False True
# False  1090     1
# True      2    35
#
#
# День: 2015-09-28 (51 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1236
#        True       1.00      1.00      1.00        39
#
# avg / total       1.00      1.00      1.00      1275
#
#       False True
# False  1236     0
# True      0    39
#
#
# День: 2015-03-28 (75 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      2712
#        True       1.00      1.00      1.00        63
#
# avg / total       1.00      1.00      1.00      2775
#
#       False True
# False  2712     0
# True      0    63
#
#
# День: 2015-12-23 (81 сообщений)
# Порог: 1.18
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3202
#        True       0.83      0.89      0.86        38
#
# avg / total       1.00      1.00      1.00      3240
#
#       False True
# False  3195     7
# True      4    34
#
#
# День: 2015-03-26 (82 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3259
#        True       1.00      0.97      0.98        62
#
# avg / total       1.00      1.00      1.00      3321
#
#       False True
# False  3259     0
# True      2    60
#
#
# День: 2015-11-27 (87 сообщений)
# Порог: 1.45
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3679
#        True       0.92      0.89      0.90        62
#
# avg / total       1.00      1.00      1.00      3741
#
#       False True
# False  3674     5
# True      7    55
#
#
# День: 2015-11-30 (94 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      4298
#        True       0.94      0.85      0.89        73
#
# avg / total       1.00      1.00      1.00      4371
#
#       False True
# False  4294     4
# True     11    62
#
#
# День: 2015-08-30 (102 сообщений)
# Порог: 1.7
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5067
#        True       0.96      0.94      0.95        84
#
# avg / total       1.00      1.00      1.00      5151
#
#       False True
# False  5064     3
# True      5    79
#
#
# День: 2016-02-06 (104 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5277
#        True       1.00      1.00      1.00        79
#
# avg / total       1.00      1.00      1.00      5356
#
#       False True
# False  5277     0
# True      0    79
#
#
# День: 2015-08-29 (111 сообщений)
# Порог: 1.22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6021
#        True       0.93      0.85      0.89        84
#
# avg / total       1.00      1.00      1.00      6105
#
#       False True
# False  6016     5
# True     13    71
#
#
# День: 2015-11-26 (118 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6812
#        True       0.92      0.87      0.89        91
#
# avg / total       1.00      1.00      1.00      6903
#
#       False True
# False  6805     7
# True     12    79
#
#
# День: 2015-09-27 (119 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6935
#        True       0.98      0.98      0.98        86
#
# avg / total       1.00      1.00      1.00      7021
#
#       False True
# False  6933     2
# True      2    84
#
#
# День: 2015-11-25 (121 сообщений)
# Порог: 1.35
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      7177
#        True       0.81      0.77      0.79        83
#
# avg / total       1.00      1.00      1.00      7260
#
#       False True
# False  7162    15
# True     19    64
#
#
# День: 2015-10-25 (144 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     10182
#        True       0.94      0.91      0.92       114
#
# avg / total       1.00      1.00      1.00     10296
#
#        False True
# False  10175     7
# True      10   104
#
#
# День: 2015-06-26 (164 сообщений)
# Порог: 1.12
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     13250
#        True       0.97      0.93      0.95       116
#
# avg / total       1.00      1.00      1.00     13366
#
#        False True
# False  13247     3
# True       8   108
#
#
# День: 2015-06-25 (217 сообщений)
# Порог: 1.41
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     23272
#        True       0.92      0.87      0.89       164
#
# avg / total       1.00      1.00      1.00     23436
#
#        False True
# False  23259    13
# True      21   143
#
#
# День: 2015-05-27 (226 сообщений)
# Порог: 1.36
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     25263
#        True       0.92      0.89      0.91       162
#
# avg / total       1.00      1.00      1.00     25425
#
#        False True
# False  25251    12
# True      18   144
#
#
# День: 2015-05-28 (236 сообщений)
# Порог: 1.34
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     27567
#        True       0.94      0.93      0.94       163
#
# avg / total       1.00      1.00      1.00     27730
#
#        False True
# False  27557    10
# True      11   152
#
#
# День: 2015-03-25 (240 сообщений)
# Порог: 1.45
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     28515
#        True       0.94      0.93      0.94       165
#
# avg / total       1.00      1.00      1.00     28680
#
#        False True
# False  28505    10
# True      11   154
#
#
# День: 2015-05-25 (259 сообщений)
# Порог: 1.45
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33225
#        True       0.87      0.87      0.87       186
#
# avg / total       1.00      1.00      1.00     33411
#
#        False True
# False  33201    24
# True      24   162
#
#
# День: 2015-02-27 (262 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     34009
#        True       0.95      0.93      0.94       182
#
# avg / total       1.00      1.00      1.00     34191
#
#        False True
# False  34000     9
# True      12   170
#
#
# День: 2015-02-25 (279 сообщений)
# Порог: 1.29
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     38577
#        True       0.98      0.95      0.96       204
#
# avg / total       1.00      1.00      1.00     38781
#
#        False True
# False  38574     3
# True      11   193
#
#
# День: 2015-05-29 (281 сообщений)
# Порог: 1.38
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39128
#        True       0.81      0.76      0.78       212
#
# avg / total       1.00      1.00      1.00     39340
#
#        False True
# False  39090    38
# True      51   161
#
#
# День: 2015-02-26 (288 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     41120
#        True       0.85      0.88      0.87       208
#
# avg / total       1.00      1.00      1.00     41328
#
#        False True
# False  41087    33
# True      24   184
#
#
# День: 2015-05-26 (315 сообщений)
# Порог: 1.47
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     49230
#        True       0.81      0.79      0.80       225
#
# avg / total       1.00      1.00      1.00     49455
#
#        False True
# False  49189    41
# True      47   178
#
#
# День: 2015-03-29 (393 сообщений)
# Порог: 1.8
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     76724
#        True       0.82      0.78      0.80       304
#
# avg / total       1.00      1.00      1.00     77028
#
#        False True
# False  76673    51
# True      68   236
#
#
# День: 2015-05-30 (523 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    136121
#        True       0.69      0.67      0.68       382
#
# avg / total       1.00      1.00      1.00    136503
#
#         False True
# False  136006   115
# True      125   257
#
#
# День: 2015-02-28 (536 сообщений)
# Порог: 1.41
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    142965
#        True       0.76      0.72      0.74       415
#
# avg / total       1.00      1.00      1.00    143380
#
#         False True
# False  142873    92
# True      118   297

# %%
results = multiprocess_optimise_th_for_days(all_days)
for day in sorted(results.keys(), key=lambda x: day_msg_count[x]):
    th, res = results[day]
    print("День: {} ({} сообщений)".format(day, day_msg_count[day]))
    print("Порог:", th)
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
# Out:
# День: 2015-10-29 (11 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       0.96      1.00      0.98        48
#        True       1.00      0.71      0.83         7
#
# avg / total       0.97      0.96      0.96        55
#
#       False True
# False    48     0
# True      2     5
#
#
# День: 2015-11-29 (15 сообщений)
# Порог: 1.06
#              precision    recall  f1-score   support
#
#       False       0.98      0.99      0.98        96
#        True       0.88      0.78      0.82         9
#
# avg / total       0.97      0.97      0.97       105
#
#       False True
# False    95     1
# True      2     7
#
#
# День: 2015-08-28 (17 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       123
#        True       1.00      1.00      1.00        13
#
# avg / total       1.00      1.00      1.00       136
#
#       False True
# False   123     0
# True      0    13
#
#
# День: 2015-01-23 (17 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       132
#        True       0.57      1.00      0.73         4
#
# avg / total       0.99      0.98      0.98       136
#
#       False True
# False   129     3
# True      0     4
#
#
# День: 2015-09-29 (18 сообщений)
# Порог: 1.1
#              precision    recall  f1-score   support
#
#       False       0.99      0.98      0.98       143
#        True       0.73      0.80      0.76        10
#
# avg / total       0.97      0.97      0.97       153
#
#       False True
# False   140     3
# True      2     8
#
#
# День: 2015-08-25 (22 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       214
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       231
#
#       False True
# False   214     0
# True      0    17
#
#
# День: 2015-01-24 (22 сообщений)
# Порог: 1.04
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       224
#        True       0.64      1.00      0.78         7
#
# avg / total       0.99      0.98      0.98       231
#
#       False True
# False   220     4
# True      0     7
#
#
# День: 2015-04-30 (24 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       255
#        True       1.00      1.00      1.00        21
#
# avg / total       1.00      1.00      1.00       276
#
#       False True
# False   255     0
# True      0    21
#
#
# День: 2015-09-26 (25 сообщений)
# Порог: 1.5
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       283
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       300
#
#       False True
# False   283     0
# True      0    17
#
#
# День: 2015-10-26 (28 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       358
#        True       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00       378
#
#       False True
# False   358     0
# True      0    20
#
#
# День: 2015-11-28 (28 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       0.99      0.99      0.99       356
#        True       0.83      0.91      0.87        22
#
# avg / total       0.98      0.98      0.98       378
#
#       False True
# False   352     4
# True      2    20
#
#
# День: 2015-10-30 (38 сообщений)
# Порог: 0.99
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      1.00       677
#        True       0.96      0.85      0.90        26
#
# avg / total       0.99      0.99      0.99       703
#
#       False True
# False   676     1
# True      4    22
#
#
# День: 2015-09-30 (41 сообщений)
# Порог: 1.02
#              precision    recall  f1-score   support
#
#       False       0.99      1.00      0.99       789
#        True       1.00      0.74      0.85        31
#
# avg / total       0.99      0.99      0.99       820
#
#       False True
# False   789     0
# True      8    23
#
#
# День: 2015-03-30 (48 сообщений)
# Порог: 1.6
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1091
#        True       0.97      0.95      0.96        37
#
# avg / total       1.00      1.00      1.00      1128
#
#       False True
# False  1090     1
# True      2    35
#
#
# День: 2015-09-28 (51 сообщений)
# Порог: 1.51
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1236
#        True       1.00      1.00      1.00        39
#
# avg / total       1.00      1.00      1.00      1275
#
#       False True
# False  1236     0
# True      0    39
#
#
# День: 2015-03-28 (75 сообщений)
# Порог: 1.39
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      2712
#        True       1.00      1.00      1.00        63
#
# avg / total       1.00      1.00      1.00      2775
#
#       False True
# False  2712     0
# True      0    63
#
#
# День: 2015-12-23 (81 сообщений)
# Порог: 1.18
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3202
#        True       0.83      0.89      0.86        38
#
# avg / total       1.00      1.00      1.00      3240
#
#       False True
# False  3195     7
# True      4    34
#
#
# День: 2015-03-26 (82 сообщений)
# Порог: 1.37
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3259
#        True       1.00      0.97      0.98        62
#
# avg / total       1.00      1.00      1.00      3321
#
#       False True
# False  3259     0
# True      2    60
#
#
# День: 2015-11-27 (87 сообщений)
# Порог: 1.38
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3679
#        True       0.92      0.89      0.90        62
#
# avg / total       1.00      1.00      1.00      3741
#
#       False True
# False  3674     5
# True      7    55
#
#
# День: 2015-11-30 (94 сообщений)
# Порог: 1.43
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      4298
#        True       0.86      0.95      0.90        73
#
# avg / total       1.00      1.00      1.00      4371
#
#       False True
# False  4287    11
# True      4    69
#
#
# День: 2015-08-30 (102 сообщений)
# Порог: 1.34
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5067
#        True       0.94      0.96      0.95        84
#
# avg / total       1.00      1.00      1.00      5151
#
#       False True
# False  5062     5
# True      3    81
#
#
# День: 2016-02-06 (104 сообщений)
# Порог: 1.3
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5277
#        True       1.00      1.00      1.00        79
#
# avg / total       1.00      1.00      1.00      5356
#
#       False True
# False  5277     0
# True      0    79
#
#
# День: 2015-08-29 (111 сообщений)
# Порог: 1.22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6021
#        True       0.90      0.86      0.88        84
#
# avg / total       1.00      1.00      1.00      6105
#
#       False True
# False  6013     8
# True     12    72
#
#
# День: 2015-11-26 (118 сообщений)
# Порог: 1.51
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6812
#        True       0.84      0.96      0.89        91
#
# avg / total       1.00      1.00      1.00      6903
#
#       False True
# False  6795    17
# True      4    87
#
#
# День: 2015-09-27 (119 сообщений)
# Порог: 1.47
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6935
#        True       0.98      0.98      0.98        86
#
# avg / total       1.00      1.00      1.00      7021
#
#       False True
# False  6933     2
# True      2    84
#
#
# День: 2015-11-25 (121 сообщений)
# Порог: 1.27
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      7177
#        True       0.81      0.82      0.81        83
#
# avg / total       1.00      1.00      1.00      7260
#
#       False True
# False  7161    16
# True     15    68
#
#
# День: 2015-10-25 (144 сообщений)
# Порог: 1.58
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     10182
#        True       0.94      0.91      0.92       114
#
# avg / total       1.00      1.00      1.00     10296
#
#        False True
# False  10175     7
# True      10   104
#
#
# День: 2015-06-26 (164 сообщений)
# Порог: 1.12
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     13250
#        True       0.97      0.93      0.95       116
#
# avg / total       1.00      1.00      1.00     13366
#
#        False True
# False  13247     3
# True       8   108
#
#
# День: 2015-06-25 (217 сообщений)
# Порог: 1.41
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     23272
#        True       0.86      0.92      0.89       164
#
# avg / total       1.00      1.00      1.00     23436
#
#        False True
# False  23248    24
# True      13   151
#
#
# День: 2015-05-27 (226 сообщений)
# Порог: 1.27
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     25263
#        True       0.90      0.88      0.89       162
#
# avg / total       1.00      1.00      1.00     25425
#
#        False True
# False  25248    15
# True      20   142
#
#
# День: 2015-05-28 (236 сообщений)
# Порог: 1.34
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     27567
#        True       0.89      0.96      0.92       163
#
# avg / total       1.00      1.00      1.00     27730
#
#        False True
# False  27547    20
# True       7   156
#
#
# День: 2015-03-25 (240 сообщений)
# Порог: 1.45
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     28515
#        True       0.89      0.96      0.92       165
#
# avg / total       1.00      1.00      1.00     28680
#
#        False True
# False  28496    19
# True       7   158
#
#
# День: 2015-05-25 (259 сообщений)
# Порог: 1.2
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33225
#        True       0.90      0.80      0.85       186
#
# avg / total       1.00      1.00      1.00     33411
#
#        False True
# False  33209    16
# True      37   149
#
#
# День: 2015-02-27 (262 сообщений)
# Порог: 1.69
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33946
#        True       0.91      0.88      0.90       245
#
# avg / total       1.00      1.00      1.00     34191
#
#        False True
# False  33926    20
# True      30   215
#
#
# День: 2015-02-25 (279 сообщений)
# Порог: 1.42
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     38565
#        True       0.98      0.92      0.95       216
#
# avg / total       1.00      1.00      1.00     38781
#
#        False True
# False  38561     4
# True      17   199
#
#
# День: 2015-05-29 (281 сообщений)
# Порог: 1.38
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39128
#        True       0.69      0.88      0.78       212
#
# avg / total       1.00      1.00      1.00     39340
#
#        False True
# False  39045    83
# True      25   187
#
#
# День: 2015-02-26 (288 сообщений)
# Порог: 1.59
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     41029
#        True       0.88      0.79      0.83       299
#
# avg / total       1.00      1.00      1.00     41328
#
#        False True
# False  40998    31
# True      63   236
#
#
# День: 2015-05-26 (315 сообщений)
# Порог: 1.33
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     49230
#        True       0.74      0.81      0.78       225
#
# avg / total       1.00      1.00      1.00     49455
#
#        False True
# False  49167    63
# True      42   183
#
#
# День: 2015-03-29 (393 сообщений)
# Порог: 1.34
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     76724
#        True       0.68      0.82      0.75       304
#
# avg / total       1.00      1.00      1.00     77028
#
#        False True
# False  76607   117
# True      54   250
#
#
# День: 2015-05-30 (523 сообщений)
# Порог: 1.4
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    136121
#        True       0.60      0.84      0.70       382
#
# avg / total       1.00      1.00      1.00    136503
#
#         False True
# False  135910   211
# True       63   319
#
#
# День: 2015-02-28 (536 сообщений)
# Порог: 1.77
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    142727
#        True       0.85      0.89      0.87       653
#
# avg / total       1.00      1.00      1.00    143380
#
#         False True
# False  142624   103
# True       69   584

# %%
data_cl = ps.read_csv("data/day-1432-cl.csv", sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
th, res = get_optimal_threshold(data_cl)
print("Порог:", th)
print(classification_report(res["y"], res["p"]))
print(cross_class_report(res), "\n\n")
# Out:
# Порог: 1.44
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1014749
#        True       0.82      0.59      0.69      1276
#
# avg / total       1.00      1.00      1.00   1016025
#
#       True     False
# True    758      518
# False   164  1014585

# %% [markdown]
# ## Анализ ошибок кластеризации

# %%
def export_clusterization_report(data_1d, cutoff, filename):
    messages, clusters = do_stem(data_1d)
    tfidf_vectorizer = TfidfVectorizer(min_df=2, max_features=10000,
        stop_words=nltk.corpus.stopwords.words('russian'))
    tfidf_matrix = tfidf_vectorizer.fit_transform(messages)
    dist_matrix = 1 - cosine_similarity(tfidf_matrix)
    linkage_matrix = ward(dist_matrix)
    labels = get_labels(linkage_matrix, len(clusters), cutoff=cutoff)
    
    res = marks_to_pairwise(clusters, labels)
    print("ДЕНЬ: {}\nСообщений: {}".format(day, len(data_1d)))
    print(classification_report(res["y"], res["p"]))
    print(cross_class_report(res), "\n\n")
    
    texts = [row["title"] + ". " + row["text"] for _, row in data_1d.iterrows()]
    results = ps.DataFrame({"message": texts, "y": clusters, "p": labels}, index=None)
    with open(filename, "w") as f:
        for _, df in results.groupby("p"):
            if len(df["y"].unique()) == 1:
                continue
            df = df.sort_values("y")
            cluster_letter = {c: l for c, l in zip(sorted(df["y"].unique()), "абвгдежзиклмно")}
            f.write("Участвующие кластеры:\n")
            for c, l in sorted(cluster_letter.items(), key=lambda x: x[0]):
                f.write("  {}) '{}'\n".format(l, c))
            f.write("Сообщения:\n")
            for _, row in df.iterrows():
                f.write("  ({}) {}\n".format(cluster_letter[row["y"]], row["message"]))
            f.write("\n")

# %%
for day in data["date"].unique():
    data_1d = data[data["date"] == day]
    if len(data_1d) < 4000:        
        export_clusterization_report(data_1d, 1.75, "reports/report-{}.txt".format(day))
# Out:
# ДЕНЬ: 2015-01-22
# Сообщений: 2
#              precision    recall  f1-score   support
#
#        True       1.00      1.00      1.00         1
#
# avg / total       1.00      1.00      1.00         1
#
#      True
# True    1
#
#
# ДЕНЬ: 2015-01-23
# Сообщений: 17
#              precision    recall  f1-score   support
#
#       False       1.00      0.86      0.93       132
#        True       0.18      1.00      0.31         4
#
# avg / total       0.98      0.87      0.91       136
#
#       False True
# False   114    18
# True      0     4
#
#
# ДЕНЬ: 2015-01-24
# Сообщений: 22
#              precision    recall  f1-score   support
#
#       False       1.00      0.93      0.96       224
#        True       0.30      1.00      0.47         7
#
# avg / total       0.98      0.93      0.95       231
#
#       False True
# False   208    16
# True      0     7
#
#
# ДЕНЬ: 2015-02-25
# Сообщений: 279
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     38577
#        True       0.84      0.96      0.89       204
#
# avg / total       1.00      1.00      1.00     38781
#
#        False True
# False  38539    38
# True       8   196
#
#
# ДЕНЬ: 2015-02-26
# Сообщений: 288
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     41120
#        True       0.62      0.92      0.74       208
#
# avg / total       1.00      1.00      1.00     41328
#
#        False True
# False  41003   117
# True      16   192
#
#
# ДЕНЬ: 2015-02-27
# Сообщений: 262
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     34009
#        True       0.70      0.98      0.81       182
#
# avg / total       1.00      1.00      1.00     34191
#
#        False True
# False  33932    77
# True       4   178
#
#
# ДЕНЬ: 2015-02-28
# Сообщений: 536
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    142965
#        True       0.57      0.93      0.70       415
#
# avg / total       1.00      1.00      1.00    143380
#
#         False True
# False  142669   296
# True       30   385
#
#
# ДЕНЬ: 2015-03-25
# Сообщений: 240
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     28515
#        True       0.77      0.98      0.86       165
#
# avg / total       1.00      1.00      1.00     28680
#
#        False True
# False  28466    49
# True       3   162
#
#
# ДЕНЬ: 2015-03-26
# Сообщений: 82
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      3259
#        True       0.85      0.97      0.90        62
#
# avg / total       1.00      1.00      1.00      3321
#
#       False True
# False  3248    11
# True      2    60
#
#
# ДЕНЬ: 2015-03-28
# Сообщений: 75
#              precision    recall  f1-score   support
#
#       False       1.00      0.99      1.00      2712
#        True       0.80      1.00      0.89        63
#
# avg / total       1.00      0.99      0.99      2775
#
#       False True
# False  2696    16
# True      0    63
#
#
# ДЕНЬ: 2015-03-29
# Сообщений: 393
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     76724
#        True       0.57      0.91      0.70       304
#
# avg / total       1.00      1.00      1.00     77028
#
#        False True
# False  76512   212
# True      27   277
#
#
# ДЕНЬ: 2015-03-30
# Сообщений: 48
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1091
#        True       0.88      0.95      0.91        37
#
# avg / total       0.99      0.99      0.99      1128
#
#       False True
# False  1086     5
# True      2    35
#
#
# ДЕНЬ: 2015-04-30
# Сообщений: 24
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       255
#        True       1.00      1.00      1.00        21
#
# avg / total       1.00      1.00      1.00       276
#
#       False True
# False   255     0
# True      0    21
#
#
# ДЕНЬ: 2015-05-25
# Сообщений: 259
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33225
#        True       0.61      0.91      0.73       186
#
# avg / total       1.00      1.00      1.00     33411
#
#        False True
# False  33115   110
# True      16   170
#
#
# ДЕНЬ: 2015-05-26
# Сообщений: 315
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     49230
#        True       0.56      0.88      0.68       225
#
# avg / total       1.00      1.00      1.00     49455
#
#        False True
# False  49074   156
# True      28   197
#
#
# ДЕНЬ: 2015-05-27
# Сообщений: 226
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     25263
#        True       0.65      0.93      0.77       162
#
# avg / total       1.00      1.00      1.00     25425
#
#        False True
# False  25183    80
# True      12   150
#
#
# ДЕНЬ: 2015-05-28
# Сообщений: 236
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     27567
#        True       0.75      0.96      0.84       163
#
# avg / total       1.00      1.00      1.00     27730
#
#        False True
# False  27515    52
# True       7   156
#
#
# ДЕНЬ: 2015-05-29
# Сообщений: 281
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39128
#        True       0.56      0.93      0.70       212
#
# avg / total       1.00      1.00      1.00     39340
#
#        False True
# False  38975   153
# True      15   197
#
#
# ДЕНЬ: 2015-05-30
# Сообщений: 523
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    136121
#        True       0.52      0.91      0.66       382
#
# avg / total       1.00      1.00      1.00    136503
#
#         False True
# False  135802   319
# True       36   346
#
#
# ДЕНЬ: 2015-06-25
# Сообщений: 217
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     23272
#        True       0.73      0.95      0.82       164
#
# avg / total       1.00      1.00      1.00     23436
#
#        False True
# False  23214    58
# True       9   155
#
#
# ДЕНЬ: 2015-06-26
# Сообщений: 164
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     13250
#        True       0.80      0.97      0.88       116
#
# avg / total       1.00      1.00      1.00     13366
#
#        False True
# False  13221    29
# True       3   113
#
#
# ДЕНЬ: 2015-08-25
# Сообщений: 22
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       214
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       231
#
#       False True
# False   214     0
# True      0    17
#
#
# ДЕНЬ: 2015-08-28
# Сообщений: 17
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       123
#        True       1.00      1.00      1.00        13
#
# avg / total       1.00      1.00      1.00       136
#
#       False True
# False   123     0
# True      0    13
#
#
# ДЕНЬ: 2015-08-29
# Сообщений: 111
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6021
#        True       0.72      0.94      0.82        84
#
# avg / total       1.00      0.99      0.99      6105
#
#       False True
# False  5991    30
# True      5    79
#
#
# ДЕНЬ: 2015-08-30
# Сообщений: 102
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5067
#        True       0.77      0.95      0.85        84
#
# avg / total       1.00      0.99      0.99      5151
#
#       False True
# False  5043    24
# True      4    80
#
#
# ДЕНЬ: 2015-09-26
# Сообщений: 25
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       283
#        True       1.00      1.00      1.00        17
#
# avg / total       1.00      1.00      1.00       300
#
#       False True
# False   283     0
# True      0    17
#
#
# ДЕНЬ: 2015-09-27
# Сообщений: 119
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      6935
#        True       0.74      0.94      0.83        86
#
# avg / total       1.00      1.00      1.00      7021
#
#       False True
# False  6906    29
# True      5    81
#
#
# ДЕНЬ: 2015-09-28
# Сообщений: 51
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      1236
#        True       0.91      1.00      0.95        39
#
# avg / total       1.00      1.00      1.00      1275
#
#       False True
# False  1232     4
# True      0    39
#
#
# ДЕНЬ: 2015-09-29
# Сообщений: 18
#              precision    recall  f1-score   support
#
#       False       0.99      0.94      0.96       143
#        True       0.50      0.80      0.62        10
#
# avg / total       0.95      0.93      0.94       153
#
#       False True
# False   135     8
# True      2     8
#
#
# ДЕНЬ: 2015-09-30
# Сообщений: 41
#              precision    recall  f1-score   support
#
#       False       0.99      0.98      0.98       789
#        True       0.58      0.81      0.68        31
#
# avg / total       0.98      0.97      0.97       820
#
#       False True
# False   771    18
# True      6    25
#
#
# ДЕНЬ: 2015-10-25
# Сообщений: 144
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     10182
#        True       0.74      0.92      0.82       114
#
# avg / total       1.00      1.00      1.00     10296
#
#        False True
# False  10145    37
# True       9   105
#
#
# ДЕНЬ: 2015-10-26
# Сообщений: 28
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00       358
#        True       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00       378
#
#       False True
# False   358     0
# True      0    20
#
#
# ДЕНЬ: 2015-10-29
# Сообщений: 11
#              precision    recall  f1-score   support
#
#       False       0.96      0.96      0.96        48
#        True       0.71      0.71      0.71         7
#
# avg / total       0.93      0.93      0.93        55
#
#       False True
# False    46     2
# True      2     5
#
#
# ДЕНЬ: 2015-10-30
# Сообщений: 38
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99       677
#        True       0.65      1.00      0.79        26
#
# avg / total       0.99      0.98      0.98       703
#
#       False True
# False   663    14
# True      0    26
#
#
# ДЕНЬ: 2015-11-25
# Сообщений: 121
#              precision    recall  f1-score   support
#
#       False       1.00      0.99      1.00      7177
#        True       0.56      0.89      0.69        83
#
# avg / total       0.99      0.99      0.99      7260
#
#       False True
# False  7119    58
# True      9    74
#
#
# ДЕНЬ: 2015-11-26
# Сообщений: 118
#              precision    recall  f1-score   support
#
#       False       1.00      0.99      1.00      6812
#        True       0.70      0.99      0.82        91
#
# avg / total       1.00      0.99      0.99      6903
#
#       False True
# False  6774    38
# True      1    90
#
#
# ДЕНЬ: 2015-11-27
# Сообщений: 87
#              precision    recall  f1-score   support
#
#       False       1.00      0.99      1.00      3679
#        True       0.65      0.94      0.77        62
#
# avg / total       0.99      0.99      0.99      3741
#
#       False True
# False  3648    31
# True      4    58
#
#
# ДЕНЬ: 2015-11-28
# Сообщений: 28
#              precision    recall  f1-score   support
#
#       False       0.99      0.98      0.99       356
#        True       0.71      0.91      0.80        22
#
# avg / total       0.98      0.97      0.98       378
#
#       False True
# False   348     8
# True      2    20
#
#
# ДЕНЬ: 2015-11-29
# Сообщений: 15
#              precision    recall  f1-score   support
#
#       False       0.98      0.94      0.96        96
#        True       0.54      0.78      0.64         9
#
# avg / total       0.94      0.92      0.93       105
#
#       False True
# False    90     6
# True      2     7
#
#
# ДЕНЬ: 2015-11-30
# Сообщений: 94
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      4298
#        True       0.79      0.95      0.86        73
#
# avg / total       1.00      0.99      1.00      4371
#
#       False True
# False  4280    18
# True      4    69
#
#
# ДЕНЬ: 2015-12-23
# Сообщений: 81
#              precision    recall  f1-score   support
#
#       False       1.00      0.98      0.99      3202
#        True       0.33      0.95      0.49        38
#
# avg / total       0.99      0.98      0.98      3240
#
#       False True
# False  3129    73
# True      2    36
#
#
# ДЕНЬ: 2016-01-26
# Сообщений: 1865
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1736676
#        True       0.44      0.43      0.44      1504
#
# avg / total       1.00      1.00      1.00   1738180
#
#          False True
# False  1735861   815
# True       857   647
#
#
# ДЕНЬ: 2016-01-28
# Сообщений: 1189
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    705376
#        True       0.62      0.88      0.73       890
#
# avg / total       1.00      1.00      1.00    706266
#
#         False True
# False  704901   475
# True      105   785
#
#
# ДЕНЬ: 2016-02-05
# Сообщений: 3553
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   6307362
#        True       0.70      0.72      0.71      2766
#
# avg / total       1.00      1.00      1.00   6310128
#
#          False True
# False  6306486   876
# True       762  2004
#
#
# ДЕНЬ: 2016-02-06
# Сообщений: 104
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00      5277
#        True       0.91      0.99      0.95        79
#
# avg / total       1.00      1.00      1.00      5356
#
#       False True
# False  5269     8
# True      1    78

# %%
for filename in ["day-1432.csv", "day-4146.csv"]:
    data_1d = ps.read_csv("data/" + filename, sep=';', header=None,
                   index_col=0,names=['id','title','text','cluster','date','publisher'])
